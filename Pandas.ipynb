# %% [markdown]
# <a href="https://colab.research.google.com/github/Benson0404/nsysuaop/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Series

# %%
# 載入Pandas模組
import pandas as pd

# 宣告建立一維資料 Series
age = [25, 30, 35, 40, 22, 29, 38, 27, 33, 31]
se = pd.Series(age)
se
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    22
# 5    29
# 6    38
# 7    27
# 8    33
# 9    31
# dtype: int64

# %%
se[3]

#用索引值名稱
se.loc[3]

#用索引值編號
se.iloc[3]
# Out:
# np.int64(40)

# %%
# 查看資料值
se.values

# 查看索引
se.index

# 查看資料型態
se.dtype
# Out:
# dtype('int64')

# %%
# 自訂索引
name = ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Helen', 'Ivy', 'Jack']
age = [25, 30, 35, 40, 22, 29, 38, 27, 33, 31]
seidx = pd.Series(age, index=name)
seidx
# Out:
# Alice      25
# Bob        30
# Charlie    35
# David      40
# Eve        22
# Frank      29
# Grace      38
# Helen      27
# Ivy        33
# Jack       31
# dtype: int64

# %%
seidx.loc['Eve']
# Out:
# np.int64(22)

# %% [markdown]
# ##DataFrame

# %%
#建立DataFrame
import pandas as pd

data = {
    'ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Helen', 'Ivy', 'Jack'],
    'Age': [25, 30, 35, 40, 22, 29, 38, 27, 33, 31],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose'],
    'Salary': [50000, 60000, 75000, 80000, 45000, 62000, 72000, 58000, 69000, 71000],
    'Department': ['IT', 'HR', 'Finance', 'Marketing', 'IT', 'HR', 'Finance', 'Marketing', 'IT', 'Finance']
}
df = pd.DataFrame(data)
df
# Out:
#     ID     Name  Age          City  Salary Department
# 0  101    Alice   25      New York   50000         IT
# 1  102      Bob   30   Los Angeles   60000         HR
# 2  103  Charlie   35       Chicago   75000    Finance
# 3  104    David   40       Houston   80000  Marketing
# 4  105      Eve   22       Phoenix   45000         IT
# 5  106    Frank   29  Philadelphia   62000         HR
# 6  107    Grace   38   San Antonio   72000    Finance
# 7  108    Helen   27     San Diego   58000  Marketing
# 8  109      Ivy   33        Dallas   69000         IT
# 9  110     Jack   31      San Jose   71000    Finance

# %%
df.values
df.index
df.columns
df.dtypes
# Out:
# ID             int64
# Name          object
# Age            int64
# City          object
# Salary         int64
# Department    object
# dtype: object

# %%
# 取得列資料
df.values[1]
df.loc[1]
df.iloc[1]
# Out:
# ID                    102
# Name                  Bob
# Age                    30
# City          Los Angeles
# Salary              60000
# Department             HR
# Name: 1, dtype: object

# %%
# 取得單欄資料
df['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# 5      Frank
# 6      Grace
# 7      Helen
# 8        Ivy
# 9       Jack
# Name: Name, dtype: object

# %%
# 取得多欄資料
df[['Name', 'Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
# 4      Eve   22
# 5    Frank   29
# 6    Grace   38
# 7    Helen   27
# 8      Ivy   33
# 9     Jack   31

# %%
# 取得指定儲存格的值
df.values[2, 1] # [列,欄]
# Out:
# 'Charlie'

# %%
# 指定範圍取值
df.iloc[2:6, 1:4]
# Out:
#       Name  Age          City
# 2  Charlie   35       Chicago
# 3    David   40       Houston
# 4      Eve   22       Phoenix
# 5    Frank   29  Philadelphia

# %%
df.loc[2:6, 'Name':'Salary']
# Out:
#       Name  Age          City  Salary
# 2  Charlie   35       Chicago   75000
# 3    David   40       Houston   80000
# 4      Eve   22       Phoenix   45000
# 5    Frank   29  Philadelphia   62000
# 6    Grace   38   San Antonio   72000

# %%
# 取得前面幾筆或最後幾筆，預設 5 筆
df.head()
df.tail(3)
# Out:
#     ID   Name  Age       City  Salary Department
# 7  108  Helen   27  San Diego   58000  Marketing
# 8  109    Ivy   33     Dallas   69000         IT
# 9  110   Jack   31   San Jose   71000    Finance

# %%
# 指定新的欄位索引
dfidx = df.set_index('ID')
dfidx
# Out:
#         Name  Age          City  Salary Department
# ID
# 101    Alice   25      New York   50000         IT
# 102      Bob   30   Los Angeles   60000         HR
# 103  Charlie   35       Chicago   75000    Finance
# 104    David   40       Houston   80000  Marketing
# 105      Eve   22       Phoenix   45000         IT
# 106    Frank   29  Philadelphia   62000         HR
# 107    Grace   38   San Antonio   72000    Finance
# 108    Helen   27     San Diego   58000  Marketing
# 109      Ivy   33        Dallas   69000         IT
# 110     Jack   31      San Jose   71000    Finance

# %%
dfidx.loc[109]
# Out:
# Name             Ivy
# Age               33
# City          Dallas
# Salary         69000
# Department        IT
# Name: 109, dtype: object

# %%
# 篩選(單一條件)
condition = df['Age'] > 30

df[condition]
# Out:
#     ID     Name  Age         City  Salary Department
# 2  103  Charlie   35      Chicago   75000    Finance
# 3  104    David   40      Houston   80000  Marketing
# 6  107    Grace   38  San Antonio   72000    Finance
# 8  109      Ivy   33       Dallas   69000         IT
# 9  110     Jack   31     San Jose   71000    Finance

# %%
more = (df['Age'] > 20) & (df['Salary'] > 70000)
df[more]
# Out:
#     ID     Name  Age         City  Salary Department
# 2  103  Charlie   35      Chicago   75000    Finance
# 3  104    David   40      Houston   80000  Marketing
# 6  107    Grace   38  San Antonio   72000    Finance
# 9  110     Jack   31     San Jose   71000    Finance

# %%
# 查看數值資料描述性統計資料
df.describe()
# Out:
#               ID        Age        Salary
# count   10.00000  10.000000     10.000000
# mean   105.50000  31.000000  64200.000000
# std      3.02765   5.656854  11193.251935
# min    101.00000  22.000000  45000.000000
# 25%    103.25000  27.500000  58500.000000
# 50%    105.50000  30.500000  65500.000000
# 75%    107.75000  34.500000  71750.000000
# max    110.00000  40.000000  80000.000000

# %%
df['Department'].unique() # 計算一個資料集 / column中不重複的資料。
df['Department'].value_counts() # 計算一個 column 中各相異值共有幾筆資料
# Out:
# Department
# IT           3
# Finance      3
# HR           2
# Marketing    2
# Name: count, dtype: int64

# %%
df['salary_rank'] = df['Salary'].rank()
df
# Out:
#     ID     Name  Age          City  Salary Department  salary_rank
# 0  101    Alice   25      New York   50000         IT          2.0
# 1  102      Bob   30   Los Angeles   60000         HR          4.0
# 2  103  Charlie   35       Chicago   75000    Finance          9.0
# 3  104    David   40       Houston   80000  Marketing         10.0
# 4  105      Eve   22       Phoenix   45000         IT          1.0
# 5  106    Frank   29  Philadelphia   62000         HR          5.0
# 6  107    Grace   38   San Antonio   72000    Finance          8.0
# 7  108    Helen   27     San Diego   58000  Marketing          3.0
# 8  109      Ivy   33        Dallas   69000         IT          6.0
# 9  110     Jack   31      San Jose   71000    Finance          7.0

# %%
# 資料排序
df.sort_values(by='Age', ascending=False)
# Out:
#     ID     Name  Age          City  Salary Department  salary_rank
# 3  104    David   40       Houston   80000  Marketing         10.0
# 6  107    Grace   38   San Antonio   72000    Finance          8.0
# 2  103  Charlie   35       Chicago   75000    Finance          9.0
# 8  109      Ivy   33        Dallas   69000         IT          6.0
# 9  110     Jack   31      San Jose   71000    Finance          7.0
# 1  102      Bob   30   Los Angeles   60000         HR          4.0
# 5  106    Frank   29  Philadelphia   62000         HR          5.0
# 7  108    Helen   27     San Diego   58000  Marketing          3.0
# 0  101    Alice   25      New York   50000         IT          2.0
# 4  105      Eve   22       Phoenix   45000         IT          1.0

# %%
df[['ID', 'Age', 'Salary']].sum(axis=1) #以欄為單位，往後執行
# Out:
# 0    50126
# 1    60132
# 2    75138
# 3    80144
# 4    45127
# 5    62135
# 6    72145
# 7    58135
# 8    69142
# 9    71141
# dtype: int64

# %%
# 依 Department 分組
grp = df.groupby('Department')
grp.get_group('IT')

grp['Salary'].mean()
# Out:
# Department
# Finance      72666.666667
# HR           61000.000000
# IT           54666.666667
# Marketing    69000.000000
# Name: Salary, dtype: float64

# %%
# 新增一個「公司名稱」欄位，所有值都為「TechCorp」
df['Company'] = 'TechCorp'
df
# Out:
#     ID     Name  Age          City  Salary Department   Company
# 0  101    Alice   25      New York   50000         IT  TechCorp
# 1  102      Bob   30   Los Angeles   60000         HR  TechCorp
# 2  103  Charlie   35       Chicago   75000    Finance  TechCorp
# 3  104    David   40       Houston   80000  Marketing  TechCorp
# 4  105      Eve   22       Phoenix   45000         IT  TechCorp
# 5  106    Frank   29  Philadelphia   62000         HR  TechCorp
# 6  107    Grace   38   San Antonio   72000    Finance  TechCorp
# 7  108    Helen   27     San Diego   58000  Marketing  TechCorp
# 8  109      Ivy   33        Dallas   69000         IT  TechCorp
# 9  110     Jack   31      San Jose   71000    Finance  TechCorp

# %%
# 新增「年薪」欄位（假設每年有 12 個月薪資）
df['Annual Salary'] = df['Salary'] * 12
df
# Out:
#     ID     Name  Age          City  Salary Department   Company  Annual Salary
# 0  101    Alice   25      New York   50000         IT  TechCorp         600000
# 1  102      Bob   30   Los Angeles   60000         HR  TechCorp         720000
# 2  103  Charlie   35       Chicago   75000    Finance  TechCorp         900000
# 3  104    David   40       Houston   80000  Marketing  TechCorp         960000
# 4  105      Eve   22       Phoenix   45000         IT  TechCorp         540000
# 5  106    Frank   29  Philadelphia   62000         HR  TechCorp         744000
# 6  107    Grace   38   San Antonio   72000    Finance  TechCorp         864000
# 7  108    Helen   27     San Diego   58000  Marketing  TechCorp         696000
# 8  109      Ivy   33        Dallas   69000         IT  TechCorp         828000
# 9  110     Jack   31      San Jose   71000    Finance  TechCorp         852000

# %%
# 新增「高薪」欄位（若薪資高於 65000 則標記為 Yes，否則為 No）
df['High Salary'] = df['Salary'].apply(lambda x: 'Yes' if x > 65000 else 'No')

def check_high_salary(x):
    if x > 65000:
        return 'Yes'
    else:
        return 'No'

df['High Salary 2'] = df['Salary'].apply(check_high_salary)

df
# Out:
#     ID     Name  Age          City  Salary Department   Company  \
# 0  101    Alice   25      New York   50000         IT  TechCorp
# 1  102      Bob   30   Los Angeles   60000         HR  TechCorp
# 2  103  Charlie   35       Chicago   75000    Finance  TechCorp
# 3  104    David   40       Houston   80000  Marketing  TechCorp
# 4  105      Eve   22       Phoenix   45000         IT  TechCorp
# 5  106    Frank   29  Philadelphia   62000         HR  TechCorp
# 6  107    Grace   38   San Antonio   72000    Finance  TechCorp
# 7  108    Helen   27     San Diego   58000  Marketing  TechCorp
# 8  109      Ivy   33        Dallas   69000         IT  TechCorp
# 9  110     Jack   31      San Jose   71000    Finance  TechCorp
#
#    Annual Salary High Salary High Salary 2
# 0         600000          No            No
# 1         720000          No            No
# 2         900000         Yes           Yes
# 3         960000         Yes           Yes
# ...

# %%
# 刪除「City」與「Department」欄位
df.drop(columns=['High Salary 2'], inplace=True)
df
# Out:
#     ID     Name  Age          City  Salary Department   Company  \
# 0  101    Alice   25      New York   50000         IT  TechCorp
# 1  102      Bob   30   Los Angeles   60000         HR  TechCorp
# 2  103  Charlie   35       Chicago   75000    Finance  TechCorp
# 3  104    David   40       Houston   80000  Marketing  TechCorp
# 4  105      Eve   22       Phoenix   45000         IT  TechCorp
# 5  106    Frank   29  Philadelphia   62000         HR  TechCorp
# 6  107    Grace   38   San Antonio   72000    Finance  TechCorp
# 7  108    Helen   27     San Diego   58000  Marketing  TechCorp
# 8  109      Ivy   33        Dallas   69000         IT  TechCorp
# 9  110     Jack   31      San Jose   71000    Finance  TechCorp
#
#    Annual Salary High Salary
# 0         600000          No
# 1         720000          No
# 2         900000         Yes
# 3         960000         Yes
# 4         540000          No
# 5         744000          No
# 6         864000         Yes
# ...

# %%
df = df.drop(columns=['High Salary'])
df
# Out:
#     ID     Name  Age          City  Salary Department   Company  Annual Salary
# 0  101    Alice   25      New York   50000         IT  TechCorp         600000
# 1  102      Bob   30   Los Angeles   60000         HR  TechCorp         720000
# 2  103  Charlie   35       Chicago   75000    Finance  TechCorp         900000
# 3  104    David   40       Houston   80000  Marketing  TechCorp         960000
# 4  105      Eve   22       Phoenix   45000         IT  TechCorp         540000
# 5  106    Frank   29  Philadelphia   62000         HR  TechCorp         744000
# 6  107    Grace   38   San Antonio   72000    Finance  TechCorp         864000
# 7  108    Helen   27     San Diego   58000  Marketing  TechCorp         696000
# 8  109      Ivy   33        Dallas   69000         IT  TechCorp         828000
# 9  110     Jack   31      San Jose   71000    Finance  TechCorp         852000

# %%
# 使用串列方式新增一筆資料（按照 DataFrame 欄位順序）
df.loc[len(df)] = [111, 'Kevin', 28, 'Austin', 67000, 'IT', 'TechCorp', '360005']
df
# Out:
#      ID     Name  Age          City  Salary Department   Company Annual Salary
# 0   101    Alice   25      New York   50000         IT  TechCorp        600000
# 1   102      Bob   30   Los Angeles   60000         HR  TechCorp        720000
# 2   103  Charlie   35       Chicago   75000    Finance  TechCorp        900000
# 3   104    David   40       Houston   80000  Marketing  TechCorp        960000
# 4   105      Eve   22       Phoenix   45000         IT  TechCorp        540000
# 5   106    Frank   29  Philadelphia   62000         HR  TechCorp        744000
# 6   107    Grace   38   San Antonio   72000    Finance  TechCorp        864000
# 7   108    Helen   27     San Diego   58000  Marketing  TechCorp        696000
# 8   109      Ivy   33        Dallas   69000         IT  TechCorp        828000
# 9   110     Jack   31      San Jose   71000    Finance  TechCorp        852000
# 10  111    Kevin   28        Austin   67000         IT  TechCorp        360005

# %%
new_data = [
    {'ID': 112, 'Name': 'Lily', 'Age': 26, 'City': 'Seattle', 'Salary': 55000, 'Department': 'Marketing'}
]
df = pd.concat([df, pd.DataFrame(new_data)], ignore_index=True)
df
# Out:
#      ID     Name  Age          City  Salary Department   Company Annual Salary
# 0   101    Alice   25      New York   50000         IT  TechCorp        600000
# 1   102      Bob   30   Los Angeles   60000         HR  TechCorp        720000
# 2   103  Charlie   35       Chicago   75000    Finance  TechCorp        900000
# 3   104    David   40       Houston   80000  Marketing  TechCorp        960000
# 4   105      Eve   22       Phoenix   45000         IT  TechCorp        540000
# 5   106    Frank   29  Philadelphia   62000         HR  TechCorp        744000
# 6   107    Grace   38   San Antonio   72000    Finance  TechCorp        864000
# 7   108    Helen   27     San Diego   58000  Marketing  TechCorp        696000
# 8   109      Ivy   33        Dallas   69000         IT  TechCorp        828000
# 9   110     Jack   31      San Jose   71000    Finance  TechCorp        852000
# 10  111    Kevin   28        Austin   67000         IT  TechCorp        360005
# ...

# %%
# 刪除索引為 2 的資料
df.drop(index=12, inplace=True) #inplace=True -> 會取代原本的dataframe
df
# Out:
#      ID   Name  Age          City  Salary Department   Company Annual Salary
# 0   101  Alice   25      New York   50000         IT  TechCorp        600000
# 1   102    Bob   30   Los Angeles   60000         HR  TechCorp        720000
# 4   105    Eve   22       Phoenix   45000         IT  TechCorp        540000
# 5   106  Frank   29  Philadelphia   62000         HR  TechCorp        744000
# 6   107  Grace   38   San Antonio   72000    Finance  TechCorp        864000
# 7   108  Helen   27     San Diego   58000  Marketing  TechCorp        696000
# 8   109    Ivy   33        Dallas   69000         IT  TechCorp        828000
# 9   110   Jack   31      San Jose   71000    Finance  TechCorp        852000
# 10  111  Kevin   28        Austin   67000         IT  TechCorp        360005
# 11  112   Lily   26       Seattle   55000  Marketing       NaN           NaN

# %%
# 刪除薪水高於 75000 的員工 -> 篩選
condition = df['Salary'] < 75000
df = df[condition]
df
# Out:
#      ID   Name  Age          City  Salary Department   Company Annual Salary
# 0   101  Alice   25      New York   50000         IT  TechCorp        600000
# 1   102    Bob   30   Los Angeles   60000         HR  TechCorp        720000
# 4   105    Eve   22       Phoenix   45000         IT  TechCorp        540000
# 5   106  Frank   29  Philadelphia   62000         HR  TechCorp        744000
# 6   107  Grace   38   San Antonio   72000    Finance  TechCorp        864000
# 7   108  Helen   27     San Diego   58000  Marketing  TechCorp        696000
# 8   109    Ivy   33        Dallas   69000         IT  TechCorp        828000
# 9   110   Jack   31      San Jose   71000    Finance  TechCorp        852000
# 10  111  Kevin   28        Austin   67000         IT  TechCorp        360005
# 11  112   Lily   26       Seattle   55000  Marketing       NaN           NaN

# %%
# 計算每一欄有多少個 NaN
df.isnull().sum()
# Out:
# ID               0
# Name             0
# Age              0
# City             0
# Salary           0
# Department       0
# Company          1
# Annual Salary    1
# dtype: int64

# %%
df.isnull()
# Out:
#        ID   Name    Age   City  Salary  Department  Company  Annual Salary
# 0   False  False  False  False   False       False    False          False
# 1   False  False  False  False   False       False    False          False
# 4   False  False  False  False   False       False    False          False
# 5   False  False  False  False   False       False    False          False
# 6   False  False  False  False   False       False    False          False
# 7   False  False  False  False   False       False    False          False
# 8   False  False  False  False   False       False    False          False
# 9   False  False  False  False   False       False    False          False
# 10  False  False  False  False   False       False    False          False
# 11  False  False  False  False   False       False     True           True

# %%
# 找出具有空值的列(回傳每一列是否「至少有一個欄位是 NaN」的布林值)
df.isnull().any(axis=1)

#只看 'ID' 和 'Name' 這兩欄
df[['ID','Name']].isnull().any(axis=1)

#直接把「至少有一個欄位是 NaN」的整列資料取出來
df[df.isnull().any(axis=1)]
# Out:
#      ID  Name  Age     City  Salary Department Company Annual Salary
# 11  112  Lily   26  Seattle   55000  Marketing     NaN           NaN

# %%
# 找出具有空值的欄
df.columns[df.isnull().any(axis=0)]
# Out:
# Index(['Company', 'Annual Salary'], dtype='object')

# %%
df.loc[4,'Salary'] = pd.NA
df
# Out:
#      ID   Name  Age          City   Salary Department   Company Annual Salary
# 0   101  Alice   25      New York  50000.0         IT  TechCorp        600000
# 1   102    Bob   30   Los Angeles  60000.0         HR  TechCorp        720000
# 4   105    Eve   22       Phoenix      NaN         IT  TechCorp        540000
# 5   106  Frank   29  Philadelphia  62000.0         HR  TechCorp        744000
# 6   107  Grace   38   San Antonio  72000.0    Finance  TechCorp        864000
# 7   108  Helen   27     San Diego  58000.0  Marketing  TechCorp        696000
# 8   109    Ivy   33        Dallas  69000.0         IT  TechCorp        828000
# 9   110   Jack   31      San Jose  71000.0    Finance  TechCorp        852000
# 10  111  Kevin   28        Austin  67000.0         IT  TechCorp        360005
# 11  112   Lily   26       Seattle  55000.0  Marketing       NaN           NaN

# %%
# 用平均數填充 Salary 欄位
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
df
# Out:
#      ID   Name  Age          City        Salary Department   Company  \
# 0   101  Alice   25      New York  50000.000000         IT  TechCorp
# 1   102    Bob   30   Los Angeles  60000.000000         HR  TechCorp
# 4   105    Eve   22       Phoenix  62666.666667         IT  TechCorp
# 5   106  Frank   29  Philadelphia  62000.000000         HR  TechCorp
# 6   107  Grace   38   San Antonio  72000.000000    Finance  TechCorp
# 7   108  Helen   27     San Diego  58000.000000  Marketing  TechCorp
# 8   109    Ivy   33        Dallas  69000.000000         IT  TechCorp
# 9   110   Jack   31      San Jose  71000.000000    Finance  TechCorp
# 10  111  Kevin   28        Austin  67000.000000         IT  TechCorp
# 11  112   Lily   26       Seattle  55000.000000  Marketing       NaN
#
#    Annual Salary
# 0         600000
# 1         720000
# 4         540000
# 5         744000
# 6         864000
# 7         696000
# 8         828000
# 9         852000
# 10        360005
# 11           NaN

# %%
# 刪除具有空值的欄
df_dropped_cols = df.dropna(axis=1)
df_dropped_cols
# Out:
#      ID   Name  Age          City        Salary Department
# 0   101  Alice   25      New York  50000.000000         IT
# 1   102    Bob   30   Los Angeles  60000.000000         HR
# 4   105    Eve   22       Phoenix  62666.666667         IT
# 5   106  Frank   29  Philadelphia  62000.000000         HR
# 6   107  Grace   38   San Antonio  72000.000000    Finance
# 7   108  Helen   27     San Diego  58000.000000  Marketing
# 8   109    Ivy   33        Dallas  69000.000000         IT
# 9   110   Jack   31      San Jose  71000.000000    Finance
# 10  111  Kevin   28        Austin  67000.000000         IT
# 11  112   Lily   26       Seattle  55000.000000  Marketing

# %% [markdown]
# ## 樞紐分析表

# %%
# 樞紐分析表
import pandas as pd

# 建立測試資料
data = {
    'Department': ['Sales', 'Sales', 'HR', 'HR', 'IT', 'IT'],
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank'],
    'Salary': [5000, 5500, 4000, 4200, 6000, 6200],
    'Year': [2023, 2023, 2023, 2024, 2023, 2024]
}
df = pd.DataFrame(data)

# %%
# 建立樞紐分析表
pivot = pd.pivot_table(df, values='Salary', index='Department', columns='Year', aggfunc='mean')
print(pivot)
# Out:
# Year          2023    2024
# Department
# HR          4000.0  4200.0
# IT          6000.0  6200.0
# Sales       5250.0     NaN

# %% [markdown]
# ## 視覺化

# %%
import matplotlib
import matplotlib.pyplot as plt
# 新增字體
matplotlib.font_manager.fontManager.addfont('taipei_sans_tc_beta.ttf')
# 設定中文字型及負號正確顯示
plt.rcParams['font.sans-serif'] = 'Taipei Sans TC Beta'
plt.rcParams["axes.unicode_minus"] = False

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    'Year': [2020, 2021, 2022, 2023],
    'Sales': [100, 150, 200, 250]
}
df = pd.DataFrame(data)
df.plot(kind='bar', x='Year', y='Sales', title='年銷售額', grid=True, color='pink', figsize=(10, 6)) #長條圖
plt.show()

# %%
# 下載台北黑體字型
# !wget -O taipei_sans_tc_beta.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download
# Out:
# --2025-04-15 08:27:02--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 172.217.204.100, 172.217.204.101, 172.217.204.113, ...
# Connecting to drive.google.com (drive.google.com)|172.217.204.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2025-04-15 08:27:02--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.216.132, 2607:f8b0:400c:c12::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘taipei_sans_tc_beta.ttf’
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 載入內建資料集
tips = sns.load_dataset("tips")

# 畫出小費 vs 消費金額的散佈圖，並依性別著色
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex")
plt.title("Total Bill vs Tip")
plt.show()
